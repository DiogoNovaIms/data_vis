# %%
import pandas as pd

# %%
gdp = pd.read_csv("gdp.csv")
gdp.head()
# Out:
#                   Country Name Code          1960          1961          1962  \
# 0                        Aruba  ABW           NaN           NaN           NaN
# 1  Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10  2.149392e+10
# 2                  Afghanistan  AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 3   Africa Western and Central  AFW  1.040428e+10  1.112805e+10  1.194335e+10
# 4                       Angola  AGO           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  2.573321e+10  2.352744e+10  2.681057e+10  2.915216e+10  3.017317e+10  ...
# 2  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 3  1.267652e+10  1.383858e+10  1.486247e+10  1.583285e+10  1.442643e+10  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
gdp_df.columns
# Out:
# Index(['Code', 'year', 'gdp', 'Country'], dtype='object')

# %%
gdp = gdp.drop(['Unnamed: 65'], axis=1)
gdp
# Out:
#                     Country Name Code          1960          1961  \
# 0                          Aruba  ABW           NaN           NaN
# 1    Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10
# 2                    Afghanistan  AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central  AFW  1.040428e+10  1.112805e+10
# 4                         Angola  AGO           NaN           NaN
# ..                           ...  ...           ...           ...
# 261                       Kosovo  XKX           NaN           NaN
# 262                  Yemen, Rep.  YEM           NaN           NaN
# 263                 South Africa  ZAF  7.575397e+09  7.972997e+09
# 264                       Zambia  ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe  ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
#Melt the columns into rows
gdp_df = pd.melt(gdp, id_vars=["Country Name", "Code"], 
                  var_name="year", value_name="gdp")

gdp_df["Country"] = gdp_df["Country Name"].str.upper()
gdp_df["year"] = gdp_df["year"].astype(int)

gdp_df.head()
# Out:
#                   Country Name Code  year           gdp  \
# 0                        Aruba  ABW  1960           NaN
# 1  Africa Eastern and Southern  AFE  1960  1.931311e+10
# 2                  Afghanistan  AFG  1960  5.377778e+08
# 3   Africa Western and Central  AFW  1960  1.040428e+10
# 4                       Angola  AGO  1960           NaN
#
#                        Country
# 0                        ARUBA
# 1  AFRICA EASTERN AND SOUTHERN
# 2                  AFGHANISTAN
# 3   AFRICA WESTERN AND CENTRAL
# 4                       ANGOLA

# %%
gdp_df = gdp_df.drop(["Country Name"], axis=1)
gdp_df
# Out:
#       Code  year           gdp                      Country
# 0      ABW  1960           NaN                        ARUBA
# 1      AFE  1960  1.931311e+10  AFRICA EASTERN AND SOUTHERN
# 2      AFG  1960  5.377778e+08                  AFGHANISTAN
# 3      AFW  1960  1.040428e+10   AFRICA WESTERN AND CENTRAL
# 4      AGO  1960           NaN                       ANGOLA
# ...    ...   ...           ...                          ...
# 16221  XKX  2020  7.716925e+09                       KOSOVO
# 16222  YEM  2020           NaN                  YEMEN, REP.
# 16223  ZAF  2020  3.354421e+11                 SOUTH AFRICA
# 16224  ZMB  2020  1.811063e+10                       ZAMBIA
# 16225  ZWE  2020  1.805117e+10                     ZIMBABWE
#
# [16226 rows x 4 columns]

# %%
temp_df = pd.read_csv("CountryTemperatures_byYear.csv").drop("Unnamed: 0", axis = 1)

temp_df["Country"] = temp_df["Country"].astype(str)
temp_df["year"] = temp_df["year"].astype(int)

temp_df.head()
# Out:
#    year         Country  AverageTemperature  AverageTemperatureUncertainty  \
# 0  1900     AFGHANISTAN           13.749333                       0.748833
# 1  1900         ALBANIA           13.068583                       0.723417
# 2  1900         ALGERIA           22.864167                       0.826667
# 3  1900  AMERICAN SAMOA           26.273500                       0.891000
# 4  1900         ANDORRA           11.348333                       0.542167
#
#    Latitude  Longitude  GHG  temp_diff
# 0     33.00       65.0  0.0        0.0
# 1     41.00       20.0  0.0        0.0
# 2     28.00        3.0  0.0        0.0
# 3    -14.33     -170.0  NaN        0.0
# 4     42.50        1.5  0.0        0.0

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16226 entries, 0 to 16225
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Code     16226 non-null  object
#  1   year     16226 non-null  int32
#  2   gdp      12840 non-null  float64
#  3   Country  16226 non-null  object
# dtypes: float64(1), int32(1), object(2)
# memory usage: 443.8+ KB

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24342 entries, 0 to 24341
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           24342 non-null  int32
#  1   Country                        24342 non-null  object
#  2   AverageTemperature             24341 non-null  float64
#  3   AverageTemperatureUncertainty  24341 non-null  float64
#  4   Latitude                       24342 non-null  float64
#  5   Longitude                      24342 non-null  float64
#  6   GHG                            22458 non-null  float64
#  7   temp_diff                      24341 non-null  float64
# dtypes: float64(6), int32(1), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Merge the two datasets by country and year

# %%
df = pd.merge(temp_df,gdp_df,on=["year","Country"],how="left")
df
# Out:
#        year                  Country  AverageTemperature  \
# 0      1900              AFGHANISTAN           13.749333
# 1      1900                  ALBANIA           13.068583
# 2      1900                  ALGERIA           22.864167
# 3      1900           AMERICAN SAMOA           26.273500
# 4      1900                  ANDORRA           11.348333
# ...     ...                      ...                 ...
# 24337  2013                  VIETNAM           25.232125
# 24338  2013  VIRGIN ISLANDS, BRITISH           27.312333
# 24339  2013                    YEMEN           28.129750
# 24340  2013                   ZAMBIA           21.196000
# 24341  2013                 ZIMBABWE           20.710750
#
#        AverageTemperatureUncertainty  Latitude  Longitude           GHG  \
# 0                           0.748833     33.00       65.0  0.000000e+00
# 1                           0.723417     41.00       20.0  0.000000e+00
# ...

# %% [markdown]
# ### Export data

# %%
df.to_csv("CountryTemperatures_byYear.csv")
